# %%
import facebook

# %%
oauth_access_token = 'CAACEdEose0cBAAX8dikCUH6ozzEzgj5xuFp96X8fJZALFL3GG3JzQe8ugYLBUQ6S8dsiMIZBs8RrAzHuGIdh8Os4Gf3rmv7PgU95H6xKYc6rsZBUUEOi3L4IUPASu94lJqXzpOaywBJTc5QGMZAconBdxK9PPAoHF2ElsQCInS1eS0gLAsV8gvTrmI3htVZBZAzm2ng5qrsgZDZD'
graph = facebook.GraphAPI(oauth_access_token)
profile = graph.get_object("comment")
friends = graph.get_connections("me", "friends")

# %%
[eme['name'] for eme in friends['data']]
# Out:
# [u'Peter Bull',
#  u'Mike Tolley',
#  u'Ryan King',
#  u'Eric Fredrickson',
#  u'Terrance Garrett',
#  u'Kevin Yuan',
#  u'Taiyo Wilson',
#  u'Ben Cook',
#  u'Maye Walraven',
#  u'Anita Mehrotra',
#  u'Olivier Courty',
#  u'Gab De Lab',
#  u'Salima Lamdouar',
#  u'Marc Hochar',
#  u'Louis Lecat',
#  u'Aomar Elalamy',
#  u'Kevin Maurice-Vallerey',
#  u'Alexandre Fosse',
#  u'Jean-Baptiste Denat',
#  u'Marion Chevillotte',
#  u'Pierre de Soissan',
#  u'Paul-Louis Laferrere',
#  u'Mehdi Esmail',
#  u'Alexandra Nikitine',
#  u'C\xe9line Batlouni',
#  u'Alexis Berson',
#  u'Henri Gouz',
#  u'Ella Hagege',
#  u'Maxime B\xe9rard',
#  u'Lucile Katch\xe9 Duez',
#  u'Olivia Bou Antoun',
#  u'Yann Fiebig',
#  u'Joe Pavlisko',
#  u'Julien Madar',
#  u'Ayman Choughari',
#  u'Marion Guergadic',
#  u'Maii Bocoum',
#  u'Arthur Chauchat',
#  u'Sandra Rosenblatt',
#  u'Farah Bm',
#  u'Julie Le Hir',
#  u'Mick Zrb',
#  u'Clara Salvetti',
#  u'Zac Taleghani',
#  u'Pierre-Antoine Mudry',
# ...
